# %%
## API is intermediatary between 2 different applications trying to talk, USER --> Client(Server)
## Client/server has auth to show what a user can see and access

# %%
##1 API TEST notebook
## Coinmarketcap

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '69991ea6-2e17-4da7-8b57-c4c81315e797',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-04-07T19:36:24.936Z', 'error_code': 0, 'error_message': None, 'elapsed': 456, 'credit_count': 1, 'notice': None, 'total_count': 9519}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10957, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from time import sleep
#       5 for i in range(333):
# ----> 6     api_runner()
#       7     print('API Runner completed')
#       8     sleep(60) #sleep for 1 minute
#
# NameError: name 'api_runner' is not defined

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video
# Out:
# {'status': {'timestamp': '2024-04-08T04:29:21.820Z', 'error_code': 0, 'error_message': None, 'elapsed': 26, 'credit_count': 1, 'notice': None, 'total_count': 9518}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10958, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             10957
# 1    1027      Ethereum    ETH      ethereum              8740
# 2     825   Tether USDt   USDT        tether             81594
# 3    1839           BNB    BNB           bnb              2132
# 4    5426        Solana    SOL        solana               649
# 5    3408          USDC   USDC      usd-coin             17980
# 6      52           XRP    XRP           xrp              1284
# 7      74      Dogecoin   DOGE      dogecoin               947
# 8    2010       Cardano    ADA       cardano              1125
# 9   11419       Toncoin    TON       toncoin               261
# 10   5805     Avalanche   AVAX     avalanche               701
# 11   5994     Shiba Inu   SHIB     shiba-inu               786
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash               871
# 13   6636      Polkadot    DOT  polkadot-new               728
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = pd.concat([df,df2], ignore_index= True)
 # OR we can use above statemtns of below statements to append the data but below statemetns pulls to a file in local drive.
    if not os.path.isfile(r"D:\Crypto API Pull\CRY_API.csv"):
        df.to_csv(r"D:\Crypto API Pull\CRY_API.csv",header = 'column_names')
    else:
        df.to_csv(r"D:\Crypto API Pull\CRY_API.csv",mode = 'a', header = False) # if file is already there then just append with mode = 'a'
    # Use this if you want to create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#         id          name symbol          slug  num_market_pairs  \
# 0        1       Bitcoin    BTC       bitcoin             10957
# 1     1027      Ethereum    ETH      ethereum              8740
# 2      825   Tether USDt   USDT        tether             81594
# 3     1839           BNB    BNB           bnb              2132
# 4     5426        Solana    SOL        solana               649
# 5     3408          USDC   USDC      usd-coin             17980
# 6       52           XRP    XRP           xrp              1284
# 7       74      Dogecoin   DOGE      dogecoin               947
# 8     2010       Cardano    ADA       cardano              1125
# 9    11419       Toncoin    TON       toncoin               261
# 10    5805     Avalanche   AVAX     avalanche               701
# 11    5994     Shiba Inu   SHIB     shiba-inu               786
# 12    1831  Bitcoin Cash    BCH  bitcoin-cash               871
# 13    6636      Polkadot    DOT  polkadot-new               728
# ...

# %%
df
# Out:
#         id          name symbol          slug  num_market_pairs  \
# 0        1       Bitcoin    BTC       bitcoin             10957
# 1     1027      Ethereum    ETH      ethereum              8740
# 2      825   Tether USDt   USDT        tether             81594
# 3     1839           BNB    BNB           bnb              2132
# 4     5426        Solana    SOL        solana               649
# 5     3408          USDC   USDC      usd-coin             17980
# 6       52           XRP    XRP           xrp              1284
# 7       74      Dogecoin   DOGE      dogecoin               947
# 8     2010       Cardano    ADA       cardano              1125
# 9    11419       Toncoin    TON       toncoin               261
# 10    5805     Avalanche   AVAX     avalanche               701
# 11    5994     Shiba Inu   SHIB     shiba-inu               786
# 12    1831  Bitcoin Cash    BCH  bitcoin-cash               871
# 13    6636      Polkadot    DOT  polkadot-new               728
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df = pd.json_normalize(data['data'])
    df['Timestamp'] = pd.to_datetime('now')
    
 # OR we can use above statemtns of below statements to append the data but below statemetns pulls to a file in local drive.
    if not os.path.isfile(r"D:\Crypto API Pull\CRY_API.csv"):
        df.to_csv(r"D:\Crypto API Pull\CRY_API.csv",header = 'column_names')
    else:
        df.to_csv(r"D:\Crypto API Pull\CRY_API.csv",mode = 'a', header = False) # if file is already there then just append with mode = 'a'
    # Use this if you want to create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(18) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[106], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(18) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             10957
# 1    1027      Ethereum    ETH      ethereum              8740
# 2     825   Tether USDt   USDT        tether             81602
# 3    1839           BNB    BNB           bnb              2132
# 4    5426        Solana    SOL        solana               649
# 5    3408          USDC   USDC      usd-coin             17982
# 6      52           XRP    XRP           xrp              1284
# 7      74      Dogecoin   DOGE      dogecoin               947
# 8    2010       Cardano    ADA       cardano              1125
# 9   11419       Toncoin    TON       toncoin               262
# 10   5805     Avalanche   AVAX     avalanche               701
# 11   5994     Shiba Inu   SHIB     shiba-inu               786
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash               871
# 13   6636      Polkadot    DOT  polkadot-new               728
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             10957
# 1    1027      Ethereum    ETH      ethereum              8740
# 2     825   Tether USDt   USDT        tether             81602
# 3    1839           BNB    BNB           bnb              2132
# 4    5426        Solana    SOL        solana               649
# 5    3408          USDC   USDC      usd-coin             17982
# 6      52           XRP    XRP           xrp              1284
# 7      74      Dogecoin   DOGE      dogecoin               947
# 8    2010       Cardano    ADA       cardano              1125
# 9   11419       Toncoin    TON       toncoin               262
# 10   5805     Avalanche   AVAX     avalanche               701
# 11   5994     Shiba Inu   SHIB     shiba-inu               786
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash               871
# 13   6636      Polkadot    DOT  polkadot-new               728
# ...

# %%
df3 = df.groupby('name',sort = False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d']].max()

# %%
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                             -0.20                          0.34
# Ethereum                            -0.34                          2.42
# Tether USDt                          0.01                         -0.03
# BNB                                 -0.44                         -0.88
# Solana                              -0.77                         -0.23
# USDC                                 0.01                         -0.01
# XRP                                 -0.34                         -0.41
# Dogecoin                            -1.38                          3.64
# Cardano                             -0.38                          0.22
# Toncoin                             -0.48                         -1.33
# Avalanche                           -0.08                          0.16
# Shiba Inu                            0.04                          2.08
# ...

# %%
df4=df3.stack()

# %%
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.20
#               quote.USD.percent_change_24h     0.34
#               quote.USD.percent_change_7d     -2.43
# Ethereum      quote.USD.percent_change_1h     -0.34
#               quote.USD.percent_change_24h     2.42
#               quote.USD.percent_change_7d     -5.22
# Tether USDt   quote.USD.percent_change_1h      0.01
#               quote.USD.percent_change_24h    -0.03
#               quote.USD.percent_change_7d     -0.04
# BNB           quote.USD.percent_change_1h     -0.44
#               quote.USD.percent_change_24h    -0.88
#               quote.USD.percent_change_7d     -4.01
# Solana        quote.USD.percent_change_1h     -0.77
#               quote.USD.percent_change_24h    -0.23
#               quote.USD.percent_change_7d    -11.70
# USDC          quote.USD.percent_change_1h      0.01
#               quote.USD.percent_change_24h    -0.01
#               quote.USD.percent_change_7d     -0.03
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
# df4  is not series and not a frame, covert to frame

# %%
df5 = df4.to_frame(name = 'values')

# %%
df5
# Out:
#                                            values
# name
# Bitcoin      quote.USD.percent_change_1h    -0.20
#              quote.USD.percent_change_24h    0.34
#              quote.USD.percent_change_7d    -2.43
# Ethereum     quote.USD.percent_change_1h    -0.34
#              quote.USD.percent_change_24h    2.42
#              quote.USD.percent_change_7d    -5.22
# Tether USDt  quote.USD.percent_change_1h     0.01
#              quote.USD.percent_change_24h   -0.03
#              quote.USD.percent_change_7d    -0.04
# BNB          quote.USD.percent_change_1h    -0.44
#              quote.USD.percent_change_24h   -0.88
#              quote.USD.percent_change_7d    -4.01
# Solana       quote.USD.percent_change_1h    -0.77
#              quote.USD.percent_change_24h   -0.23
#              quote.USD.percent_change_7d   -11.70
# USDC         quote.USD.percent_change_1h     0.01
#              quote.USD.percent_change_24h   -0.01
#              quote.USD.percent_change_7d    -0.03
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df6=df5.reset_index()

# %%
df7=df6.rename(columns = {'level_1':'% Change'})

# %%
df7
# Out:
#             name                      % Change  values
# 0        Bitcoin   quote.USD.percent_change_1h   -0.20
# 1        Bitcoin  quote.USD.percent_change_24h    0.34
# 2        Bitcoin   quote.USD.percent_change_7d   -2.43
# 3       Ethereum   quote.USD.percent_change_1h   -0.34
# 4       Ethereum  quote.USD.percent_change_24h    2.42
# 5       Ethereum   quote.USD.percent_change_7d   -5.22
# 6    Tether USDt   quote.USD.percent_change_1h    0.01
# 7    Tether USDt  quote.USD.percent_change_24h   -0.03
# 8    Tether USDt   quote.USD.percent_change_7d   -0.04
# 9            BNB   quote.USD.percent_change_1h   -0.44
# 10           BNB  quote.USD.percent_change_24h   -0.88
# 11           BNB   quote.USD.percent_change_7d   -4.01
# 12        Solana   quote.USD.percent_change_1h   -0.77
# 13        Solana  quote.USD.percent_change_24h   -0.23
# 14        Solana   quote.USD.percent_change_7d  -11.70
# 15          USDC   quote.USD.percent_change_1h    0.01
# ...

# %%
df7['% Change']=df7['% Change'].replace (['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d'],['1h','24H','Week'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='% Change', y ='values',hue = 'name',data = df7, kind = 'point')

# %%
df12=df[['name','quote.USD.price','Timestamp']]
df12
# Out:
#             name  quote.USD.price                  Timestamp
# 0        Bitcoin         69273.78 2024-04-07 20:41:36.975219
# 1       Ethereum          3437.52 2024-04-07 20:41:36.975219
# 2    Tether USDt             1.00 2024-04-07 20:41:36.975219
# 3            BNB           581.69 2024-04-07 20:41:36.975219
# 4         Solana           177.91 2024-04-07 20:41:36.975219
# 5           USDC             1.00 2024-04-07 20:41:36.975219
# 6            XRP             0.59 2024-04-07 20:41:36.975219
# 7       Dogecoin             0.20 2024-04-07 20:41:36.975219
# 8        Cardano             0.59 2024-04-07 20:41:36.975219
# 9        Toncoin             5.34 2024-04-07 20:41:36.975219
# 10     Avalanche            48.51 2024-04-07 20:41:36.975219
# 11     Shiba Inu             0.00 2024-04-07 20:41:36.975219
# 12  Bitcoin Cash           691.25 2024-04-07 20:41:36.975219
# 13      Polkadot             8.66 2024-04-07 20:41:36.975219
# ...

# %%
sns.catplot(x='Timestamp',y='quote.USD.price', data = df12, hue='name')
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
